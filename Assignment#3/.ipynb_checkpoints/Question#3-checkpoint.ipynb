# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift
from sklearn.cluster import KMedoids
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21424\1216606917.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 from sklearn.cluster import KMeans
# ----> 4 from sklearn.cluster import KMedoids
#       5 from sklearn.cluster import MeanShift
#
# ImportError: cannot import name 'KMedoids' from 'sklearn.cluster' (C:\Users\Aquib Javed\anaconda3\lib\site-packages\sklearn\cluster\__init__.py)

# %%
df = pd.read_excel("Data.xlsx", header=None)
column_names = ['A4', 'B4', 'C4', 'D4'] 
df.columns = column_names

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A4      150 non-null    float64
#  1   B4      150 non-null    float64
#  2   C4      150 non-null    float64
#  3   D4      150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
kmeans = KMeans(n_clusters=3).fit(df)
kmeanslabels = kmeans.labels_

# %%
plt.scatter(df['A4'], df['B4'], c=labels, cmap='rainbow')
plt.title(f'K-means Clustering with K={3}')
plt.xlabel('A4')
plt.ylabel('B4')
plt.show()

# %%
kmedoids = KMedoids(n_clusters=3).fit(df)
kmedoidslabels = kmedoids.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21424\609576014.py in <module>
# ----> 1 kmedoids = KMedoids(n_clusters=3).fit(df)
#       2 kmedoidslabels = kmedoids.labels_
#
# NameError: name 'KMedoids' is not defined
